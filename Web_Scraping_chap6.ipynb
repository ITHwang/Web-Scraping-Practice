# %% [markdown]
# ## 폴더에 파일 저장하기

# %%
from urllib.request import urlretrieve
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# 원격 url의 파일 내려받기
html = urlopen('http://www.pythonscraping.com')
bs = BeautifulSoup(html, 'html.parser')
imageLocation = bs.find('a', {'id':'logo'}).find('img')['src']
urlretrieve(imageLocation, 'logo.jpg')
# Out:
# ('logo.jpg', <http.client.HTTPMessage at 0x2257eb30730>)

# %%
import os

downloadDirectory = 'downloaded'
baseUrl = 'http://pythonscraping.com'

def getAbsoluteURL(baseUrl, source):
    if source.startswith('http://www.'):
        url = 'http://{}'.format(source[11:])
    elif source.startswith('https://') or source.startswith('http://'):
        url = source
    elif source.startswith('www.'):
        url = source[4:]
        url = 'http://{}'.format(source)
    else:
        url = '{}/{}'.format(baseUrl, source)
    if baseUrl not in url:
        return None
    return url

# %%
def getDownloadPath(baseUrl, absoluteUrl, downloadDirectory):
    path = absoluteUrl.replace('www', '')
    path = path.replace(baseUrl, '')
    path = downloadDirectory + path
    directory = os.path.dirname(path)
    
    if not os.path.exists(directory):
        os.makedirs(directory)
        
    return path

# %%
# src 속성이 있는 태그에 연결된 내부 파일을 모두 내려받습니다.

html = urlopen('http://www.pythonscraping.com')
bs = BeautifulSoup(html, 'html.parser')
downloadList = bs.find_all(src=True)

for download in downloadList:
    fileUrl = getAbsoluteURL(baseUrl, download['src'])
    if fileUrl is not None:
        print(fileUrl)
        if  fileUrl[-4:] == '.jpg':
            urlretrieve(fileUrl, getDownloadPath(baseUrl, fileUrl, downloadDirectory))
# Out:
# http://pythonscraping.com/misc/jquery.js?v=1.4.4
# http://pythonscraping.com/misc/jquery.once.js?v=1.2
# http://pythonscraping.com/misc/drupal.js?q4na2g
# http://pythonscraping.com/sites/all/themes/skeletontheme/js/jquery.mobilemenu.js?q4na2g
# http://pythonscraping.com/sites/all/modules/google_analytics/googleanalytics.js?q4na2g
# http://pythonscraping.com/sites/default/files/lrg_0.jpg
# http://pythonscraping.com/img/lrg%20(1).jpg

# %% [markdown]
# ## csv로 저장하기

# %%
import csv

csvFile = open('test.csv', 'w+')

try:
    writer = csv.writer(csvFile)
    writer.writerow(('number', 'number plus 2', 'number times 2'))
    for i in range(10):
        writer.writerow((i, i+2, i*2))
finally:
    csvFile.close()

# %%
# html 테이블로 csv 파일 만들기

html = urlopen('http://en.wikipedia.org/wiki/Comparison_of_text_editors')
bs = BeautifulSoup(html, 'html.parser')
# 첫 번째 테이블로 만들기
table = bs.findAll('table', {'class':'wikitable'})[0]
rows = table.findAll('tr')

csvFile = open('editors.csv', 'wt+', encoding='utf-8')
writer = csv.writer(csvFile)

try:
    for row in rows:
        csvRow = []
        for cell in row.findAll(['td', 'th']):
            csvRow.append(cell.get_text())
        writer.writerow(csvRow)
finally:
    csvFile.close()

# %% [markdown]
# ## MySQL과 연동하기

# %% [markdown]
# ```sql
# CREATE DATABASE scraping;
#
# USE scraping;
#
# CREATE TABLE pages (
#     id BIGINT(7) NOT NULL AUTO_INCREMENT,
#     title VARCHAR(200),
#     content VARCHAR(10000),
#     created TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     PRIMARY KEY(id));
#
# INSERT INTO pages (title, content) VALUES ("Test page title", "This is some test page content. It can be up to 10,000 characters long.");
#
# ```

# %%
import pymysql

conn = pymysql.connect(host='127.0.0.1',
                      user='root', passwd='1234', db='mysql')
cur = conn.cursor()
cur.execute("USE scraping")
cur.execute("SELECT * FROM pages WHERE id=1")
print(cur.fetchone())

cur.close()
conn.close()
# Out:
# (1, 'test page title', 'this is some test page content. It can be up to 10,000 characters long.', datetime.datetime(2021, 7, 19, 15, 50, 15))

# %% [markdown]
# MySQL은 기본적으로 유니코드를 처리하지 않습니다. 다행히 이 기능을 켤 수는 있습니다.
#
# 유니코드긴 하지만 지원이 형편없는 utf8mb4에서 utf8mb4_unicode_ci로 바꿉니다.
#
# ```sql
# ALTER DATABASE scraping CHARACTER SET = utf8mb4 COLLATE = utf8mb4_unicode_ci;
#
# ALTER TABLE pages CONVERT TO CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;
#
# ALTER TABLE pages CHANGE title title VARCHAR(200) CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;
#
# ALTER TABLE pages CHANGE content content VARCHAR(10000) CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;
# ```

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import pymysql
import re

# %%
conn = pymysql.connect(host='127.0.0.1', user='root', passwd='1234', db='mysql', charset='utf8')
cur = conn.cursor()
cur.execute('USE scraping')

def store(title, content):
    cur.execute('INSERT INTO pages (title, content) VALUES ("%s", "%s")',
               (title, content))
    cur.connection.commit()

# %%
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org' + articleUrl)
    bs = BeautifulSoup(html, 'html.parser')
    title = bs.find('h1').get_text()
    content = bs.find('div', {'id':'mw-content-text'}).find('p').get_text()
    store(title, content)
    return bs.find('div', {'id':'bodyContent'}).findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))

# %%
random.seed(datetime.datetime.now())

links = getLinks('/wiki/Kevin_Bacon')
try:
    while len(links) > 0:
        newArticle = links[random.randint(0, len(links)-1)].attrs['href']
        print(newArticle)
        links = getLinks(newArticle)
finally:
    cur.close()
    conn.close()
# Out:
# /wiki/Mickey_Rooney
# /wiki/The_Beast_of_the_City
# /wiki/Mismates
# /wiki/Red,_White_and_Blue_Blood
# /wiki/Babette_(film)
# /wiki/New_Morals_for_Old
# /wiki/Charles_Brabin
# /wiki/Theda_Bara
# /wiki/Josephine_Baker
# /wiki/Stork_Club
# /wiki/Open_access
# /wiki/National_Institutes_of_Health
# /wiki/MRNA-1273
# /wiki/Hib_vaccine
# /wiki/Pneumonia
# /wiki/COPD
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Publications_Office_(European_Union)
# /wiki/Diplomatic_missions_of_the_European_Commission
# /wiki/List_of_diplomatic_missions_of_Europe
# /wiki/European_Union_Operations_Centre
# /wiki/Kortenberg_building
# /wiki/European_Organisation_of_Military_Associations
# /wiki/Luxembourg_Army#Luxembourg_Army_Air_Force
# /wiki/EUBG_2014_II
# /wiki/Luxembourg
# /wiki/Holy_Roman_Empire
# /wiki/Francia
# /wiki/Provisional_Government_of_the_French_Republic
# /wiki/Free_France
# /wiki/Timeline_of_World_War_II_(1943)
# /wiki/Military_history_of_the_Philippines_during_World_War_II
# /wiki/First_Indochina_War
# /wiki/Greek_Civil_War
# /wiki/Parataxis
# /wiki/Parmenides
# /wiki/Encyclop%C3%A6dia_Britannica_Eleventh_Edition
# /wiki/Beriberi
# /wiki/PMID_(identifier)
# /wiki/Tele-epidemiology
# /wiki/Remote_surgery
# /wiki/PubMed
# /wiki/List_of_academic_databases_and_search_engines
# /wiki/Scientometrics
# /wiki/Positivism
# /wiki/R._G._Collingwood
# /wiki/Big_History
# /wiki/Historiography
# /wiki/Black_people#Northern_Africa
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_18000
# /wiki/ISO_217
# /wiki/ISO_11940
# /wiki/ISO/IEC_8859-7
# /wiki/Code_page_1162
# /wiki/FDI_World_Dental_Federation_notation
# /wiki/Universal_numbering_system_(dental)
# /wiki/Molar_(tooth)
# /wiki/Molar_(unit)
# /wiki/Suspension_(chemistry)
# /wiki/Chewing_gum
# /wiki/Intravitreal_administration
# /wiki/Diabetic_retinopathy
# /wiki/Glaucoma
# /wiki/PMID_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Index_Medicus
# /wiki/PubMed
# /wiki/PMCID
# /wiki/Office_of_Science_and_Technology_Policy
# /wiki/NASA
# /wiki/Private_spaceflight
# /wiki/Israel
# /wiki/Malcolm_Yapp
# /wiki/Peter_Malcolm_Holt
# /wiki/SOAS,_University_of_London
# /wiki/Public_university
# /wiki/List_of_universities_in_Argentina
# /wiki/Latin_American_Social_Sciences_Institute
# /wiki/Guatemala
# /wiki/Tamale
# /wiki/Mesoamerica
# /wiki/Aegean_Islands
# /wiki/Cunda_Island
# /wiki/Lale_Island
# /wiki/Great_Ilyosta_Island
# /wiki/Yass%C4%B1ada
# /wiki/Sapl%C4%B1_Islet
# /wiki/Sodakrom
# /wiki/Turkey
# /wiki/Cinema_of_Turkey
# /wiki/Women_in_Turkey
# /wiki/Energy_in_Turkey
# /wiki/Euronews
# /wiki/News_broadcasting
# /wiki/Public_relations
# /wiki/Spin_(propaganda)
# /wiki/Media_censorship_and_disinformation_during_the_Gezi_Park_protests
# /wiki/Taksim_Military_Barracks
# /wiki/The_New_Republic
# /wiki/Zadie_Smith
# /wiki/Cees_Nooteboom
# /wiki/Fernanda_Pivano
# /wiki/Serena_Vitale
# /wiki/Italo_Calvino
# /wiki/Ministry_of_Agriculture
# /wiki/North_Macedonia
# /wiki/Macedonism
# /wiki/Muslim_Independence_Movement
# /wiki/Ozamiz_Ferry_Bombing
# /wiki/Maute_group
# /wiki/2017_London_Bridge_attack
# /wiki/Northern_Iraq_offensive_(August_2014)
# /wiki/Qalamoun_offensive_(May%E2%80%93June_2015)
# /wiki/Timeline_of_the_Syrian_civil_war_(January%E2%80%93April_2018)
# /wiki/Farid_Ghadry
# /wiki/Human_rights_in_Syria
# /wiki/2017_al-Jinah_airstrike
# /wiki/Islamist_uprising_in_Syria
# /wiki/War_in_Iraq_(2013%E2%80%932017)
# /wiki/Sexual_violence_in_the_Iraqi_insurgency
# /wiki/Abu_Ali_al-Anbari
# /wiki/Haji_Bakr
# /wiki/Northern_Aleppo_offensive_(February%E2%80%93July_2014)
# /wiki/Battle_of_Qalamoun
# /wiki/2016_Movida_Bar_grenade_attack
# /wiki/September_2018_Kabul_attacks
# /wiki/2017_Supreme_Court_of_Afghanistan_bombing
# /wiki/May_2020_Afghanistan_attacks
# /wiki/February_2016_Kabul_bombing
# /wiki/Operation_Pickaxe-Handle
# /wiki/Operation_Mountain_Thrust
# /wiki/2015_Khost_suicide_bombing
# /wiki/2008_Kandahar_bombing
# /wiki/2018_Inter-Continental_Hotel_Kabul_attack
# /wiki/2021_Kabul_school_bombing
# /wiki/January_2017_Afghanistan_bombings
# /wiki/20_October_2017_Afghanistan_attacks
# /wiki/March_2018_Kabul_suicide_bombing
# /wiki/Metrojet_Flight_9268
# /wiki/Battle_of_Markada
# /wiki/January_2016_Sayyidah_Zaynab_attack
# /wiki/National_Front_for_Liberation
# /wiki/2014_Syrian_presidential_election
# /wiki/Council_of_Ministers_(Syria)
# /wiki/Cabinet_of_Myanmar
# /wiki/Ministry_of_Investment_and_Foreign_Economic_Relations
# /wiki/President_of_Myanmar
# /wiki/Khin_Maung_Swe
# /wiki/Incumbent
# /wiki/Election
# /wiki/Garrat_Elections
# /wiki/England
# /wiki/Birmingham_Triennial_Music_Festival
# /wiki/World_War_I
# /wiki/Franco-Prussian_War
# /wiki/Paris_Commune
# /wiki/Owenism
# /wiki/Agent-owned_company
# /wiki/Brand
# /wiki/The_Economist
# /wiki/Global_Liveability_Survey
# /wiki/Vancouver
# /wiki/1992_Winter_Paralympics
# /wiki/Denmark_at_the_1992_Winter_Paralympics
# /wiki/France_at_the_1992_Winter_Paralympics
# /wiki/France_at_the_2006_Winter_Paralympics
# /wiki/Denmark_at_the_2006_Winter_Paralympics
# /wiki/Italy
# /wiki/Italian_Empire
# /wiki/Italian_irredentism_in_Istria
# /wiki/Chagos_Archipelago_sovereignty_dispute
# /wiki/United_Nations_General_Assembly
# /wiki/Special_Court_for_Sierra_Leone
# /wiki/Samoa
# /wiki/Asian_Development_Bank
# /wiki/Federated_States_of_Micronesia
# /wiki/Cook_Islands
# /wiki/Terrae_Incognitae_(journal)
# /wiki/History
# /wiki/Horology
# /wiki/Marine_chronometer
# /wiki/Timeline
# /wiki/Seriation_(archaeology)
# /wiki/Era
# /wiki/Regnal_year
# /wiki/Orders_of_magnitude_(time)
# /wiki/Proton_decay
# /wiki/SU(5)
# /wiki/Solenoid_(mathematics)
# /wiki/Orthogonal_group
# /wiki/Principal_homogeneous_space
# /wiki/Zbl_(identifier)
# /wiki/Carl_Runge
# /wiki/Felix_Klein
# /wiki/Doi_(identifier)
# /wiki/MPEG-4_Part_14
# /wiki/Digital_Rights_Management
# /wiki/Personal_computer
# /wiki/Microsoft_Works
# /wiki/ICalendar
# /wiki/Open_format
# /wiki/Proprietary_software
# /wiki/MacOS
# /wiki/Windows_NT
# /wiki/Software_developer
# /wiki/Source_code_editor
# /wiki/Programming_tool
# /wiki/Compiler
# /wiki/Preprocessor
# /wiki/Directive_(programming)
# /wiki/PL/SQL
# /wiki/Associative_array
# /wiki/Recursive_data_type
# /wiki/Directed_graph
# /wiki/Set_(mathematics)
# /wiki/Logical_consequence
# /wiki/Semantics_of_logic
# /wiki/Benjamin_Lee_Whorf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-f337cd130fdd> in <module>
#       6         newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#       7         print(newArticle)
# ----> 8         links = getLinks(newArticle)
#       9 finally:
#      10     cur.close()
#
# <ipython-input-37-2c1c6bd68fd5> in getLinks(articleUrl)
#       1 def getLinks(articleUrl):
# ----> 2     html = urlopen('http://en.wikipedia.org' + articleUrl)
#       3     bs = BeautifulSoup(html, 'html.parser')
#       4     title = bs.find('h1').get_text()
#       5     content = bs.find('div', {'id':'mw-content-text'}).find('p').get_text()
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1395
#    1396         def https_open(self, req):
# -> 1397             return self.do_open(http.client.HTTPSConnection, req,
#    1398                 context=self._context, check_hostname=self._check_hostname)
#    1399
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1356             except OSError as err: # timeout error
#    1357                 raise URLError(err)
# -> 1358             r = h.getresponse()
#    1359         except:
#    1360             h.close()
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 보다 효율적으로 크롤링하기

# %% [markdown]
# 테이블 두 개 만들기
# 1. 페이지 목록
# 2. 두 페이지를 잇는 링크 목록

# %% [markdown]
# ```sql
# create DATABASE wikipedia;
# USE wikipedia;
#
# CREATE TABLE pages (
# 	id INT NOT NULL auto_increment,
#     url varchar(255) not null,
#     created timestamp not null default current_timestamp,
#     primary key(id));
#
# create table links (
# 	id int not null auto_increment,
#     fromPageId int null,
#     toPageId int null,
#     created timestamp not null default current_timestamp,
#     primary key(id));
#
# commit;
# ```

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pymysql
from random import shuffle

# %%
conn = pymysql.connect(host='127.0.0.1', user='root', passwd='1234', db='mysql', charset='utf8')
cur = conn.cursor()
cur.execute('USE wikipedia')
# Out:
# 0

# %%
# 새 페이지를 발견할 때마다 저장(중복 방지)
def insertPageIfNotExists(url):
    cur.execute('SELECT * FROM pages WHERE url = %s', (url))
    if cur.rowcount == 0: # 새 페이지면
        cur.execute('INSERT INTO pages (url) VALUES (%s)', (url))
        conn.commit()
        # 마지막 로우 번호 반환
        return cur.lastrowid
    else:
        return cur.fetchone()[0]

# %%
# DB에 저장된 페이지 모두 반환
def loadPages():
    cur.execute('SELECT * FROM pages')
    pages = [row[1] for row in cur.fetchall()] # 칼럼 'url' 가져오기
    return pages

# %%
# 링크 기록하기
def insertLink(fromPageId, toPageId):
    cur.execute('SELECT * FROM links WHERE fromPageId = %s AND toPageId = %s',
                   (int(fromPageId), int(toPageId)))
    if cur.rowcount == 0:
        cur.execute('INSERT INTO links (fromPageId, toPageId) VALUES (%s, %s)',
                   (int(fromPageId), int(toPageId)))
        conn.commit()

# %%
# 링크 테이블에서 toPageId를 갖고 있는지 확인
def pageHasLinks(pageId):
    cur.execute('SELECT * FROM links WHERE fromPageId = %s', (int(pageId)))
    rowcount = cur.rowcount
    if rowcount == 0:
        return False
    return True

# %%
# 위키백과의 여섯 다리 문제
# 5번째 재귀일 때 중단
def getLinks(pageUrl, recursionLevel, pages):
    if recursionLevel > 4:
        return
    
    pageId = insertPageIfNotExists(pageUrl) # fromPageId
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    
    links = bs.findAll('a', href=re.compile('^(/wiki/)((?!:).)*$'))
    links = [link.attrs['href'] for link in links] 
    
    for link in links:
        linkId = insertPageIfNotExists(link) # toPageId
        insertLink(pageId, linkId)
        
        if not pageHasLinks(linkId): # fromPageId로 저장되어 있지 않으면
            print("PAGE HAS NO LINKS: {}".format(link))
            pages.append(link) # 페이지 리스트에 추가
            getLinks(link, recursionLevel+1, pages)

# %%
getLinks('/wiki/Kevin_Bacon', 0, loadPages())
cur.close()
conn.close()
# Out:
# PAGE HAS NO LINKS: /wiki/Kevin_Bacon_(disambiguation)
# PAGE HAS NO LINKS: /wiki/Kevin_Bacon_(producer)
# PAGE HAS NO LINKS: /wiki/Rotherham
# PAGE HAS NO LINKS: /wiki/Rotherham_(disambiguation)
# PAGE HAS NO LINKS: /wiki/Rotherham_(UK_Parliament_constituency)
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/Rotherham,_New_Zealand
# PAGE HAS NO LINKS: /wiki/Alan_Rotherham
# PAGE HAS NO LINKS: /wiki/Arthur_Rotherham
# PAGE HAS NO LINKS: /wiki/Gerard_Rotherham
# PAGE HAS NO LINKS: /wiki/Hugh_Rotherham
# PAGE HAS NO LINKS: /wiki/Joseph_Bryant_Rotherham
# PAGE HAS NO LINKS: /wiki/Roland_Rotherham
# PAGE HAS NO LINKS: /wiki/Thomas_Rotherham
# PAGE HAS NO LINKS: /wiki/Edward_Rotheram
# PAGE HAS NO LINKS: /wiki/Steve_Rotheram
# PAGE HAS NO LINKS: /wiki/HMS_Rotherham_(H09)
# PAGE HAS NO LINKS: /wiki/Baron_Rotherham
# PAGE HAS NO LINKS: /wiki/Rotherham_United_F.C.
# PAGE HAS NO LINKS: /wiki/Rotherham_child_sexual_exploitation_scandal
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Yorkshire_South_(disambiguation)
# PAGE HAS NO LINKS: /wiki/Metropolitan_county
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Geographic_coordinate_system
# PAGE HAS NO LINKS: /wiki/List_of_sovereign_states
# PAGE HAS NO LINKS: /wiki/United_Kingdom
# PAGE HAS NO LINKS: /wiki/Countries_of_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/England
# PAGE HAS NO LINKS: /wiki/Regions_of_England
# PAGE HAS NO LINKS: /wiki/Yorkshire_and_the_Humber
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1972
# PAGE HAS NO LINKS: /wiki/Time_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Greenwich_Mean_Time
# PAGE HAS NO LINKS: /wiki/Daylight_saving_time
# PAGE HAS NO LINKS: /wiki/British_Summer_Time
# PAGE HAS NO LINKS: /wiki/List_of_Parliamentary_constituencies_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Police
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Lord_Lieutenant_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/High_Sheriff_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/List_of_ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Metropolitan_county
# PAGE HAS NO LINKS: /wiki/Combined_authority
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Mayoral_Combined_Authority
# PAGE HAS NO LINKS: /wiki/Mayor_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Dan_Jarvis
# PAGE HAS NO LINKS: /wiki/Labour_Party_(UK)
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Joint_Secretariat
# PAGE HAS NO LINKS: /wiki/Sheffield
# PAGE HAS NO LINKS: /wiki/ONS_coding_system
# PAGE HAS NO LINKS: /wiki/ONS_coding_system
# PAGE HAS NO LINKS: /wiki/NUTS_of_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/Districts_of_England
# PAGE HAS NO LINKS: /wiki/City_of_Sheffield
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/Ceremonial_county
# PAGE HAS NO LINKS: /wiki/Metropolitan_county
# PAGE HAS NO LINKS: /wiki/England
# PAGE HAS NO LINKS: /wiki/Yorkshire_and_the_Humber
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/City_of_Sheffield
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1972
# PAGE HAS NO LINKS: /wiki/Sheffield
# PAGE HAS NO LINKS: /wiki/Pennines
# PAGE HAS NO LINKS: /wiki/Derbyshire
# PAGE HAS NO LINKS: /wiki/West_Yorkshire
# PAGE HAS NO LINKS: /wiki/North_Yorkshire
# PAGE HAS NO LINKS: /wiki/East_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Lincolnshire
# PAGE HAS NO LINKS: /wiki/Nottinghamshire
# PAGE HAS NO LINKS: /wiki/Sheffield_Urban_Area
# PAGE HAS NO LINKS: /wiki/List_of_urban_areas_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Sheffield_City_Region
# PAGE HAS NO LINKS: /wiki/Leeds_City_Region
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_County_Council
# PAGE HAS NO LINKS: /wiki/Unitary_authority
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Lord_Lieutenant_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/High_Sheriff_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/West_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Administrative_counties_of_England
# PAGE HAS NO LINKS: /wiki/County_borough
# PAGE HAS NO LINKS: /wiki/History_of_Sheffield
# PAGE HAS NO LINKS: /wiki/History_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Prehistoric
# PAGE HAS NO LINKS: /wiki/Mesolithic
# PAGE HAS NO LINKS: /wiki/Deepcar
# PAGE HAS NO LINKS: /wiki/Creswell_Crags
# PAGE HAS NO LINKS: /wiki/Derbyshire
# PAGE HAS NO LINKS: /wiki/Upper_Palaeolithic
# PAGE HAS NO LINKS: /wiki/Mining
# PAGE HAS NO LINKS: /wiki/Steel
# PAGE HAS NO LINKS: /wiki/Pennines
# PAGE HAS NO LINKS: /wiki/Nonconformist_(Protestantism)
# PAGE HAS NO LINKS: /wiki/Mill_town
# PAGE HAS NO LINKS: /wiki/Methodist
# PAGE HAS NO LINKS: /wiki/Baptist
# PAGE HAS NO LINKS: /wiki/Spiritualism
# PAGE HAS NO LINKS: /wiki/Spiritualists%27_National_Union
# PAGE HAS NO LINKS: /wiki/Redcliffe-Maud_Report
# PAGE HAS NO LINKS: /wiki/Local_Government_Commission_for_England_(1958%E2%80%931967)
# PAGE HAS NO LINKS: /wiki/Redcliffe-Maud_Report
# PAGE HAS NO LINKS: /wiki/Urban_district_(Great_Britain_and_Ireland)
# PAGE HAS NO LINKS: /wiki/Rural_district
# PAGE HAS NO LINKS: /wiki/1970_United_Kingdom_general_election
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1972
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1888
# PAGE HAS NO LINKS: /wiki/County_borough
# PAGE HAS NO LINKS: /wiki/Municipal_borough
# PAGE HAS NO LINKS: /wiki/Urban_district_(Great_Britain_and_Ireland)
# PAGE HAS NO LINKS: /wiki/Rural_district
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/County_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/Cudworth_Urban_District
# PAGE HAS NO LINKS: /wiki/Darfield_Urban_District
# PAGE HAS NO LINKS: /wiki/Darton_Urban_District
# PAGE HAS NO LINKS: /wiki/Dearne_Urban_District
# PAGE HAS NO LINKS: /wiki/Dodworth_Urban_District
# PAGE HAS NO LINKS: /wiki/Hoyland_Nether_Urban_District
# PAGE HAS NO LINKS: /wiki/Penistone_Urban_District
# PAGE HAS NO LINKS: /wiki/Royston,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Wombwell_Urban_District
# PAGE HAS NO LINKS: /wiki/Worsbrough_Urban_District
# PAGE HAS NO LINKS: /wiki/Hemsworth_Rural_District
# PAGE HAS NO LINKS: /wiki/Penistone_Rural_District
# PAGE HAS NO LINKS: /wiki/Wortley_Rural_District
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/County_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/Adwick_le_Street_Urban_District
# PAGE HAS NO LINKS: /wiki/Bentley_with_Arksey
# PAGE HAS NO LINKS: /wiki/Conisbrough_Urban_District
# PAGE HAS NO LINKS: /wiki/Mexborough_Urban_District
# PAGE HAS NO LINKS: /wiki/Tickhill_Urban_District
# PAGE HAS NO LINKS: /wiki/Doncaster_Rural_District
# PAGE HAS NO LINKS: /wiki/East_Retford_Rural_District
# PAGE HAS NO LINKS: /wiki/Thorne_Rural_District
# PAGE HAS NO LINKS: /wiki/Worksop_Rural_District
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/County_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/Maltby_Urban_District
# PAGE HAS NO LINKS: /wiki/Swinton_Urban_District
# PAGE HAS NO LINKS: /wiki/Rawmarsh_Urban_District
# PAGE HAS NO LINKS: /wiki/Wath_upon_Dearne_Urban_District
# PAGE HAS NO LINKS: /wiki/Kiveton_Park_Rural_District
# PAGE HAS NO LINKS: /wiki/Rotherham_Rural_District
# PAGE HAS NO LINKS: /wiki/City_of_Sheffield
# PAGE HAS NO LINKS: /wiki/County_Borough_of_Sheffield
# PAGE HAS NO LINKS: /wiki/Stocksbridge_Urban_District
# PAGE HAS NO LINKS: /wiki/Wortley_Rural_District
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1972
# PAGE HAS NO LINKS: /wiki/Local_government_in_England
# PAGE HAS NO LINKS: /wiki/Metropolitan_and_non-metropolitan_counties_of_England
# PAGE HAS NO LINKS: /wiki/Districts_of_England
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_County_Council
# PAGE HAS NO LINKS: /wiki/1973_United_Kingdom_local_elections
# PAGE HAS NO LINKS: /wiki/The_Times
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Passenger_Transport_Executive
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Police_and_Crime_Commissioner
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Police
# PAGE HAS NO LINKS: /wiki/Metropolitan_and_non-metropolitan_counties_of_England
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Lord_Lieutenant_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/High_Sheriff_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Derbyshire
# PAGE HAS NO LINKS: /wiki/West_Yorkshire
# PAGE HAS NO LINKS: /wiki/North_Yorkshire
# PAGE HAS NO LINKS: /wiki/East_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Lincolnshire
# PAGE HAS NO LINKS: /wiki/Nottinghamshire
# PAGE HAS NO LINKS: /wiki/Humberhead_Levels
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Coalfield
# PAGE HAS NO LINKS: /wiki/Peak_District
# PAGE HAS NO LINKS: /wiki/Dark_Peak
# PAGE HAS NO LINKS: /wiki/River_Dearne
# PAGE HAS NO LINKS: /wiki/River_Rother,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/River_Don,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/South_and_West_Yorkshire_Green_Belt
# PAGE HAS NO LINKS: /wiki/Green_belt_(United_Kingdom)
# PAGE HAS NO LINKS: /wiki/List_of_settlements_in_South_Yorkshire_by_population
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/Barnsley
# PAGE HAS NO LINKS: /wiki/Billingley
# PAGE HAS NO LINKS: /wiki/Birdwell,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Cudworth,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Darfield,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Darton
# PAGE HAS NO LINKS: /wiki/Dodworth
# PAGE HAS NO LINKS: /wiki/Great_Houghton,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Grimethorpe
# PAGE HAS NO LINKS: /wiki/Hoyland
# PAGE HAS NO LINKS: /wiki/Royston,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Penistone
# PAGE HAS NO LINKS: /wiki/Thurnscoe
# PAGE HAS NO LINKS: /wiki/Wombwell
# PAGE HAS NO LINKS: /wiki/Worsbrough
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/Doncaster
# PAGE HAS NO LINKS: /wiki/Adwick_le_Street
# PAGE HAS NO LINKS: /wiki/Armthorpe
# PAGE HAS NO LINKS: /wiki/Askern
# PAGE HAS NO LINKS: /wiki/Auckley
# PAGE HAS NO LINKS: /wiki/Balby
# PAGE HAS NO LINKS: /wiki/Barnby_Dun
# PAGE HAS NO LINKS: /wiki/Bawtry
# PAGE HAS NO LINKS: /wiki/Bentley,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Bessacarr
# PAGE HAS NO LINKS: /wiki/Braithwell
# PAGE HAS NO LINKS: /wiki/Branton,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Cantley,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Carcroft
# PAGE HAS NO LINKS: /wiki/Conisbrough
# PAGE HAS NO LINKS: /wiki/Cusworth
# PAGE HAS NO LINKS: /wiki/Denaby
# PAGE HAS NO LINKS: /wiki/Dunscroft
# PAGE HAS NO LINKS: /wiki/Dunsville
# PAGE HAS NO LINKS: /wiki/Edenthorpe
# PAGE HAS NO LINKS: /wiki/Edlington
# PAGE HAS NO LINKS: /wiki/Finningley
# PAGE HAS NO LINKS: /wiki/Fishlake
# PAGE HAS NO LINKS: /wiki/Hatfield,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Hyde_Park,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Intake,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Kirk_Sandall
# PAGE HAS NO LINKS: /wiki/Loversall
# PAGE HAS NO LINKS: /wiki/Marr,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Mexborough
# PAGE HAS NO LINKS: /wiki/Micklebring
# PAGE HAS NO LINKS: /wiki/Moorends
# PAGE HAS NO LINKS: /wiki/Scawsby
# PAGE HAS NO LINKS: /wiki/Scawthorpe
# PAGE HAS NO LINKS: /wiki/Skellow
# PAGE HAS NO LINKS: /wiki/Stainforth,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Rossington
# PAGE HAS NO LINKS: /wiki/Sykehouse
# PAGE HAS NO LINKS: /wiki/Norton,_Doncaster
# PAGE HAS NO LINKS: /wiki/Thorne,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Tickhill
# PAGE HAS NO LINKS: /wiki/Wadworth
# PAGE HAS NO LINKS: /wiki/Warmsworth
# PAGE HAS NO LINKS: /wiki/Wheatley_Hills
# PAGE HAS NO LINKS: /wiki/Wheatley_Hills
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/Anston
# PAGE HAS NO LINKS: /wiki/Aughton,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Brinsworth
# PAGE HAS NO LINKS: /wiki/Dinnington,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Harthill,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Kiveton_Park
# PAGE HAS NO LINKS: /wiki/Maltby,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Rawmarsh
# PAGE HAS NO LINKS: /wiki/Scholes,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Swinton,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Thorpe_Hesley
# PAGE HAS NO LINKS: /wiki/Todwick
# PAGE HAS NO LINKS: /wiki/Treeton
# PAGE HAS NO LINKS: /wiki/Thurcroft
# PAGE HAS NO LINKS: /wiki/Wales,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Wath-upon-Dearne
# PAGE HAS NO LINKS: /wiki/Bolton-upon-Dearne
# PAGE HAS NO LINKS: /wiki/Woodsetts
# PAGE HAS NO LINKS: /wiki/Whiston,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/City_of_Sheffield
# PAGE HAS NO LINKS: /wiki/Sheffield_City_Centre
# PAGE HAS NO LINKS: /wiki/Beighton,_Sheffield
# PAGE HAS NO LINKS: /wiki/Chapeltown,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Highlane,_Derbyshire
# PAGE HAS NO LINKS: /wiki/Mosborough
# PAGE HAS NO LINKS: /wiki/Oughtibridge
# PAGE HAS NO LINKS: /wiki/Stocksbridge
# PAGE HAS NO LINKS: /wiki/Wharncliffe_Side
# PAGE HAS NO LINKS: /wiki/Dearne_Valley
# PAGE HAS NO LINKS: /wiki/Sheffield_urban_area
# PAGE HAS NO LINKS: /wiki/List_of_civil_parishes_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_County_Council
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_County_Council
# PAGE HAS NO LINKS: /wiki/Sheffield
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Fire_and_Rescue_Authority
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Passenger_Transport_Executive
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Pensions_Authority
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Police_and_Crime_Panel
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Joint_Secretariat
# PAGE HAS NO LINKS: /wiki/Barnsley
# PAGE HAS NO LINKS: /wiki/Metropolitan_and_non-metropolitan_counties_of_England
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Lord_Lieutenant_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/High_Sheriff_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/South_Yorkshire_Mayoral_Combined_Authority
# PAGE HAS NO LINKS: /wiki/Mayor_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/2016_United_Kingdom_European_Union_membership_referendum
# PAGE HAS NO LINKS: /wiki/European_Regional_Development_Fund
# PAGE HAS NO LINKS: /wiki/List_of_monastic_houses_in_England
# PAGE HAS NO LINKS: /wiki/List_of_amusement_parks_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/List_of_castles_in_England
# PAGE HAS NO LINKS: /wiki/Country_park
# PAGE HAS NO LINKS: /wiki/English_Heritage
# PAGE HAS NO LINKS: /wiki/Forestry_Commission
# PAGE HAS NO LINKS: /wiki/List_of_British_heritage_and_private_railways#England
# PAGE HAS NO LINKS: /wiki/List_of_historic_houses_in_England
# PAGE HAS NO LINKS: /wiki/List_of_mosques_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/List_of_museums_in_England
# PAGE HAS NO LINKS: /wiki/National_Trust_for_Places_of_Historic_Interest_or_Natural_Beauty
# PAGE HAS NO LINKS: /wiki/Theater_(structure)
# PAGE HAS NO LINKS: /wiki/List_of_zoos_by_country#United_Kingdom
# PAGE HAS NO LINKS: /wiki/Culture_of_Sheffield
# PAGE HAS NO LINKS: /wiki/Abbeydale_Industrial_Hamlet
# PAGE HAS NO LINKS: /wiki/Brodsworth_Hall
# PAGE HAS NO LINKS: /wiki/Cannon_Hall
# PAGE HAS NO LINKS: /wiki/Chapel_of_Our_Lady_of_Rotherham_Bridge
# PAGE HAS NO LINKS: /wiki/Clifton_Park_Museum
# PAGE HAS NO LINKS: /wiki/Conisbrough_Castle
# PAGE HAS NO LINKS: /wiki/Cusworth_Hall
# PAGE HAS NO LINKS: /wiki/Doncaster_Minster
# PAGE HAS NO LINKS: /wiki/Mansion_House,_Doncaster
# PAGE HAS NO LINKS: /wiki/Elsecar_Steam_Railway
# PAGE HAS NO LINKS: /wiki/Howden_Edge
# PAGE HAS NO LINKS: /wiki/Kelham_Island_Museum
# PAGE HAS NO LINKS: /wiki/Sheffield
# PAGE HAS NO LINKS: /wiki/Magna_Science_Adventure_Centre
# PAGE HAS NO LINKS: /wiki/Meadowhall_Centre
# PAGE HAS NO LINKS: /wiki/Monk_Bretton_Priory
# PAGE HAS NO LINKS: /wiki/Pot_House_Hamlet
# PAGE HAS NO LINKS: /wiki/Sheffield_Winter_Gardens
# PAGE HAS NO LINKS: /wiki/Roche_Abbey
# PAGE HAS NO LINKS: /wiki/Rotherham_Minster
# PAGE HAS NO LINKS: /wiki/Rother_Valley_Country_Park
# PAGE HAS NO LINKS: /wiki/RSPB_Old_Moor_Wetland_Centre
# PAGE HAS NO LINKS: /wiki/Sheffield_Cathedral
# PAGE HAS NO LINKS: /wiki/Ulley_Reservoir
# PAGE HAS NO LINKS: /wiki/Wentworth_Castle
# PAGE HAS NO LINKS: /wiki/Wentworth_Woodhouse
# PAGE HAS NO LINKS: /wiki/Weston_Park_Museum
# PAGE HAS NO LINKS: /wiki/Woodlands,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Worsbrough_Mill
# PAGE HAS NO LINKS: /wiki/Wortley_Top_Forge
# PAGE HAS NO LINKS: /wiki/Yorkshire_Wildlife_Park
# PAGE HAS NO LINKS: /wiki/The_London_Gazette
# PAGE HAS NO LINKS: /wiki/Wayback_Machine
# PAGE HAS NO LINKS: /wiki/Office_of_the_Deputy_Prime_Minister
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/Doi_(identifier)
# PAGE HAS NO LINKS: /wiki/Doi_(identifier)
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1972
# PAGE HAS NO LINKS: /wiki/The_Times
# PAGE HAS NO LINKS: /wiki/Wayback_Machine
# PAGE HAS NO LINKS: /wiki/Wayback_Machine
# PAGE HAS NO LINKS: /wiki/English_Heritage_Archive
# PAGE HAS NO LINKS: /wiki/Curlie
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/City_of_Sheffield
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/Askern
# PAGE HAS NO LINKS: /wiki/Barnsley
# PAGE HAS NO LINKS: /wiki/Bawtry
# PAGE HAS NO LINKS: /wiki/Brierley
# PAGE HAS NO LINKS: /wiki/Conisbrough
# PAGE HAS NO LINKS: /wiki/Dinnington,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Doncaster
# PAGE HAS NO LINKS: /wiki/Edlington
# PAGE HAS NO LINKS: /wiki/Hatfield,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Hoyland
# PAGE HAS NO LINKS: /wiki/Kiveton_Park
# PAGE HAS NO LINKS: /wiki/Maltby,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Mexborough
# PAGE HAS NO LINKS: /wiki/Penistone
# PAGE HAS NO LINKS: /wiki/Sheffield
# PAGE HAS NO LINKS: /wiki/Stainforth,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Stocksbridge
# PAGE HAS NO LINKS: /wiki/Swinton,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Thorne,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Tickhill
# PAGE HAS NO LINKS: /wiki/Wath_upon_Dearne
# PAGE HAS NO LINKS: /wiki/Wombwell
# PAGE HAS NO LINKS: /wiki/List_of_civil_parishes_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/River_Dearne
# PAGE HAS NO LINKS: /wiki/River_Don,_Yorkshire
# PAGE HAS NO LINKS: /wiki/River_Dove,_Barnsley
# PAGE HAS NO LINKS: /wiki/River_Idle
# PAGE HAS NO LINKS: /wiki/River_Loxley
# PAGE HAS NO LINKS: /wiki/River_Rivelin
# PAGE HAS NO LINKS: /wiki/River_Rother,_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/River_Sheaf
# PAGE HAS NO LINKS: /wiki/River_Torne
# PAGE HAS NO LINKS: /wiki/List_of_places_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_settlements_in_South_Yorkshire_by_population
# PAGE HAS NO LINKS: /wiki/List_of_Sites_of_Special_Scientific_Interest_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/High_Sheriff_of_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Castles_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Grade_I_listed_buildings_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Grade_II*_listed_buildings_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_people_from_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_monastic_houses_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_rivers_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_windmills_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_museums_in_South_Yorkshire
# PAGE HAS NO LINKS: /wiki/Yorkshire
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/East_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/North_Yorkshire
# PAGE HAS NO LINKS: /wiki/West_Yorkshire
# PAGE HAS NO LINKS: /wiki/History_of_local_government_in_Yorkshire
# PAGE HAS NO LINKS: /wiki/East_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/North_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/West_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Ainsty
# PAGE HAS NO LINKS: /wiki/List_of_wapentakes_in_Yorkshire
# PAGE HAS NO LINKS: /wiki/High_Sheriff_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Geology_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Topographical_areas_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/List_of_places_in_Yorkshire
# PAGE HAS NO LINKS: /wiki/History_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Brigantes
# PAGE HAS NO LINKS: /wiki/Parisii_(Yorkshire)
# PAGE HAS NO LINKS: /wiki/Roman_Britain
# PAGE HAS NO LINKS: /wiki/Elmet
# PAGE HAS NO LINKS: /wiki/History_of_York
# PAGE HAS NO LINKS: /wiki/Deira
# PAGE HAS NO LINKS: /wiki/Northumbria
# PAGE HAS NO LINKS: /wiki/Scandinavian_York
# PAGE HAS NO LINKS: /wiki/Wars_of_the_Roses
# PAGE HAS NO LINKS: /wiki/1931_Dogger_Bank_earthquake
# PAGE HAS NO LINKS: /wiki/Culture_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Yorkshire_dialect
# PAGE HAS NO LINKS: /wiki/Tourism_in_Yorkshire
# PAGE HAS NO LINKS: /wiki/On_Ilkla_Moor_Baht_%27at
# PAGE HAS NO LINKS: /wiki/List_of_people_from_Yorkshire
# PAGE HAS NO LINKS: /wiki/Flags_and_symbols_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/White_Rose_of_York
# PAGE HAS NO LINKS: /wiki/Yorkshire_Day
# PAGE HAS NO LINKS: /wiki/God%27s_Own_Country#Yorkshire
# PAGE HAS NO LINKS: /wiki/Districts_of_England
# PAGE HAS NO LINKS: /wiki/Yorkshire_and_the_Humber
# PAGE HAS NO LINKS: /wiki/Lincolnshire
# PAGE HAS NO LINKS: /wiki/North_Lincolnshire
# PAGE HAS NO LINKS: /wiki/North_East_Lincolnshire
# PAGE HAS NO LINKS: /wiki/North_Yorkshire
# PAGE HAS NO LINKS: /wiki/Craven
# PAGE HAS NO LINKS: /wiki/Hambleton_District
# PAGE HAS NO LINKS: /wiki/Borough_of_Harrogate
# PAGE HAS NO LINKS: /wiki/Richmondshire
# PAGE HAS NO LINKS: /wiki/Ryedale
# PAGE HAS NO LINKS: /wiki/Borough_of_Scarborough
# PAGE HAS NO LINKS: /wiki/Selby_District
# PAGE HAS NO LINKS: /wiki/York
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Barnsley
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Doncaster
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# PAGE HAS NO LINKS: /wiki/City_of_Sheffield
# PAGE HAS NO LINKS: /wiki/West_Yorkshire
# PAGE HAS NO LINKS: /wiki/City_of_Bradford
# PAGE HAS NO LINKS: /wiki/Calderdale
# PAGE HAS NO LINKS: /wiki/Kirklees
# PAGE HAS NO LINKS: /wiki/City_of_Leeds
# PAGE HAS NO LINKS: /wiki/City_of_Wakefield
# PAGE HAS NO LINKS: /wiki/East_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/East_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/Kingston_upon_Hull
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Bedfordshire
# PAGE HAS NO LINKS: /wiki/Berkshire
# PAGE HAS NO LINKS: /wiki/Bristol
# PAGE HAS NO LINKS: /wiki/Buckinghamshire
# PAGE HAS NO LINKS: /wiki/Cambridgeshire
# PAGE HAS NO LINKS: /wiki/Cheshire
# PAGE HAS NO LINKS: /wiki/Cornwall
# PAGE HAS NO LINKS: /wiki/Cumbria
# PAGE HAS NO LINKS: /wiki/Derbyshire
# PAGE HAS NO LINKS: /wiki/Devon
# PAGE HAS NO LINKS: /wiki/Dorset
# PAGE HAS NO LINKS: /wiki/County_Durham
# PAGE HAS NO LINKS: /wiki/East_Riding_of_Yorkshire
# PAGE HAS NO LINKS: /wiki/East_Sussex
# PAGE HAS NO LINKS: /wiki/Essex
# PAGE HAS NO LINKS: /wiki/Gloucestershire
# PAGE HAS NO LINKS: /wiki/Greater_London
# PAGE HAS NO LINKS: /wiki/Greater_Manchester
# PAGE HAS NO LINKS: /wiki/Hampshire
# PAGE HAS NO LINKS: /wiki/Herefordshire
# PAGE HAS NO LINKS: /wiki/Hertfordshire
# PAGE HAS NO LINKS: /wiki/Isle_of_Wight
# PAGE HAS NO LINKS: /wiki/Kent
# PAGE HAS NO LINKS: /wiki/Lancashire
# PAGE HAS NO LINKS: /wiki/Leicestershire
# PAGE HAS NO LINKS: /wiki/Lincolnshire
# PAGE HAS NO LINKS: /wiki/City_of_London
# PAGE HAS NO LINKS: /wiki/Merseyside
# PAGE HAS NO LINKS: /wiki/Norfolk
# PAGE HAS NO LINKS: /wiki/Northamptonshire
# PAGE HAS NO LINKS: /wiki/Northumberland
# PAGE HAS NO LINKS: /wiki/North_Yorkshire
# PAGE HAS NO LINKS: /wiki/Nottinghamshire
# PAGE HAS NO LINKS: /wiki/Oxfordshire
# PAGE HAS NO LINKS: /wiki/Rutland
# PAGE HAS NO LINKS: /wiki/Shropshire
# PAGE HAS NO LINKS: /wiki/Somerset
# PAGE HAS NO LINKS: /wiki/Staffordshire
# PAGE HAS NO LINKS: /wiki/Suffolk
# PAGE HAS NO LINKS: /wiki/Surrey
# PAGE HAS NO LINKS: /wiki/Tyne_and_Wear
# PAGE HAS NO LINKS: /wiki/Warwickshire
# PAGE HAS NO LINKS: /wiki/West_Midlands_(county)
# PAGE HAS NO LINKS: /wiki/West_Sussex
# PAGE HAS NO LINKS: /wiki/West_Yorkshire
# PAGE HAS NO LINKS: /wiki/Wiltshire
# PAGE HAS NO LINKS: /wiki/Worcestershire
# PAGE HAS NO LINKS: /wiki/Metropolitan_county
# PAGE HAS NO LINKS: /wiki/Greater_Manchester
# PAGE HAS NO LINKS: /wiki/Merseyside
# PAGE HAS NO LINKS: /wiki/Tyne_and_Wear
# PAGE HAS NO LINKS: /wiki/West_Midlands_(county)
# PAGE HAS NO LINKS: /wiki/West_Yorkshire
# PAGE HAS NO LINKS: /wiki/MBAREA_(identifier)
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/United_Kingdom_Census_2011
# PAGE HAS NO LINKS: /wiki/2001_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/2021_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/United_Kingdom_of_Great_Britain_and_Northern_Ireland
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/Census_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Internet
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/England
# PAGE HAS NO LINKS: /wiki/Wales
# PAGE HAS NO LINKS: /wiki/General_Register_Office_for_Scotland
# PAGE HAS NO LINKS: /wiki/Scotland
# PAGE HAS NO LINKS: /wiki/Northern_Ireland_Statistics_and_Research_Agency
# PAGE HAS NO LINKS: /wiki/Northern_Ireland
# PAGE HAS NO LINKS: /wiki/UK_Statistics_Authority
# PAGE HAS NO LINKS: /wiki/List_of_national_and_international_statistical_services
# PAGE HAS NO LINKS: /wiki/John_Rickman_(parliamentary_official)
# PAGE HAS NO LINKS: /wiki/Jil_Matheson
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/Lockheed_Martin_UK
# PAGE HAS NO LINKS: /wiki/Census_Act_1920
# PAGE HAS NO LINKS: /wiki/Lockheed_Martin_UK
# PAGE HAS NO LINKS: /wiki/Aerospace_manufacturer
# PAGE HAS NO LINKS: /wiki/Defense_(military)
# PAGE HAS NO LINKS: /wiki/Information_security
# PAGE HAS NO LINKS: /wiki/Lockheed_Martin
# PAGE HAS NO LINKS: /wiki/PATRIOT_Act
# PAGE HAS NO LINKS: /wiki/Cabinet_Office
# PAGE HAS NO LINKS: /wiki/Stop_the_War_Coalition
# PAGE HAS NO LINKS: /wiki/Ekklesia_(think_tank)
# PAGE HAS NO LINKS: /wiki/Central_Intelligence_Agency
# PAGE HAS NO LINKS: /wiki/Green_Party_of_England_and_Wales
# PAGE HAS NO LINKS: /wiki/Liberal_Conspiracy
# PAGE HAS NO LINKS: /wiki/Lancaster,_Lancashire
# PAGE HAS NO LINKS: /wiki/London_Borough_of_Newham
# PAGE HAS NO LINKS: /wiki/Isle_of_Anglesey
# PAGE HAS NO LINKS: /wiki/Birmingham
# PAGE HAS NO LINKS: /wiki/Capita_Group
# PAGE HAS NO LINKS: /wiki/Angela_Smith,_Baroness_Smith_of_Basildon
# PAGE HAS NO LINKS: /wiki/Cameron%E2%80%93Clegg_coalition
# PAGE HAS NO LINKS: /wiki/Beyond_2011
# PAGE HAS NO LINKS: /wiki/United_Kingdom_Census_2021
# PAGE HAS NO LINKS: /wiki/United_Kingdom_Census_2001
# PAGE HAS NO LINKS: /wiki/Civil_Partnership_Act_2004
# PAGE HAS NO LINKS: /wiki/Equality_and_Human_Rights_Commission
# PAGE HAS NO LINKS: /wiki/Sexual_orientation
# PAGE HAS NO LINKS: /wiki/English_people
# PAGE HAS NO LINKS: /wiki/Northern_Irish_people
# PAGE HAS NO LINKS: /wiki/Scottish_people
# PAGE HAS NO LINKS: /wiki/Welsh_people
# PAGE HAS NO LINKS: /wiki/English_language
# PAGE HAS NO LINKS: /wiki/Romani_people
# PAGE HAS NO LINKS: /wiki/Irish_Traveller
# PAGE HAS NO LINKS: /wiki/British_Arabs
# PAGE HAS NO LINKS: /wiki/British_Chinese
# PAGE HAS NO LINKS: /wiki/British_Asian
# PAGE HAS NO LINKS: /wiki/South_Asia
# PAGE HAS NO LINKS: /wiki/Origami
# PAGE HAS NO LINKS: /wiki/Cornwall
# PAGE HAS NO LINKS: /wiki/Cornish_people
# PAGE HAS NO LINKS: /wiki/Conservative_Party_(UK)
# PAGE HAS NO LINKS: /wiki/Privacy_law
# PAGE HAS NO LINKS: /wiki/Francis_Maude
# PAGE HAS NO LINKS: /wiki/Beyond_2011
# PAGE HAS NO LINKS: /wiki/Cornish_people
# PAGE HAS NO LINKS: /wiki/White_British
# PAGE HAS NO LINKS: /wiki/Cornwall_Council
# PAGE HAS NO LINKS: /wiki/British_Humanist_Association
# PAGE HAS NO LINKS: /wiki/Leading_question
# PAGE HAS NO LINKS: /wiki/Northern_Ireland_Statistics_and_Research_Agency
# PAGE HAS NO LINKS: /wiki/Lockheed_Martin_UK
# PAGE HAS NO LINKS: /wiki/General_Register_Office_for_Scotland
# PAGE HAS NO LINKS: /wiki/National_Records_of_Scotland
# PAGE HAS NO LINKS: /wiki/CACI
# PAGE HAS NO LINKS: /wiki/CACI
# PAGE HAS NO LINKS: /wiki/Abu_Ghraib
# PAGE HAS NO LINKS: /wiki/Edinburgh
# PAGE HAS NO LINKS: /wiki/Lewis_and_Harris
# PAGE HAS NO LINKS: /wiki/Scots_language
# PAGE HAS NO LINKS: /wiki/Scottish_Gaelic
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/General_Register_Office_for_Scotland
# PAGE HAS NO LINKS: /wiki/Northern_Ireland_Statistics_and_Research_Agency
# PAGE HAS NO LINKS: /wiki/Univariate
# PAGE HAS NO LINKS: /wiki/Comma-separated_values
# PAGE HAS NO LINKS: /wiki/Census_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/Cabinet_Office
# PAGE HAS NO LINKS: /wiki/Office_of_Public_Sector_Information
# PAGE HAS NO LINKS: /wiki/ISBN_(identifier)
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/Capita_Group
# PAGE HAS NO LINKS: /wiki/The_Independent
# PAGE HAS NO LINKS: /wiki/Pink_News
# PAGE HAS NO LINKS: /wiki/BBC_News
# PAGE HAS NO LINKS: /wiki/BBC_News
# PAGE HAS NO LINKS: /wiki/Daily_Express
# PAGE HAS NO LINKS: /wiki/BBC_News
# PAGE HAS NO LINKS: /wiki/The_Independent
# PAGE HAS NO LINKS: /wiki/Wayback_Machine
# PAGE HAS NO LINKS: /wiki/Office_for_National_Statistics
# PAGE HAS NO LINKS: /wiki/United_Kingdom_Census_2001
# PAGE HAS NO LINKS: /wiki/Census_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/United_Kingdom_Census_2021
# PAGE HAS NO LINKS: /wiki/Census_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/List_of_United_Kingdom_censuses
# PAGE HAS NO LINKS: /wiki/Census_Act_1800#Administration_of_the_1801_census
# PAGE HAS NO LINKS: /wiki/1841_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1851_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1861_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1871_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1881_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1891_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1901_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1911_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/Census_of_Ireland,_1911
# PAGE HAS NO LINKS: /wiki/National_Registration_Act_1939
# PAGE HAS NO LINKS: /wiki/1921_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1931_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1951_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1961_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1966_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1971_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1981_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/1991_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/2001_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/2021_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/Census_Act_1800
# PAGE HAS NO LINKS: /wiki/Census_(Great_Britain)_Act_1900
# PAGE HAS NO LINKS: /wiki/Census_Act_1920
# PAGE HAS NO LINKS: /wiki/Census_Act_(Northern_Ireland)_1969
# PAGE HAS NO LINKS: /wiki/Census_(Confidentiality)_Act_1991
# PAGE HAS NO LINKS: /wiki/Census_(Amendment)_Act_2000
# PAGE HAS NO LINKS: /wiki/Annual_Population_Survey
# PAGE HAS NO LINKS: /wiki/Beyond_2011
# PAGE HAS NO LINKS: /wiki/Census_Enumerators%27_Books
# PAGE HAS NO LINKS: /wiki/UK_Data_Service
# PAGE HAS NO LINKS: /wiki/2011_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/2011_United_Kingdom_census
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Ordnance_Survey_National_Grid
# PAGE HAS NO LINKS: /wiki/National_Grid_(Great_Britain)
# PAGE HAS NO LINKS: /wiki/Geodesy
# PAGE HAS NO LINKS: /wiki/Geodesy
# PAGE HAS NO LINKS: /wiki/Geodynamics
# PAGE HAS NO LINKS: /wiki/Geomatics
# PAGE HAS NO LINKS: /wiki/History_of_geodesy
# PAGE HAS NO LINKS: /wiki/Geographical_distance
# PAGE HAS NO LINKS: /wiki/Geoid
# PAGE HAS NO LINKS: /wiki/Figure_of_the_Earth
# PAGE HAS NO LINKS: /wiki/Earth_radius
# PAGE HAS NO LINKS: /wiki/Earth%27s_circumference
# PAGE HAS NO LINKS: /wiki/Geodetic_datum
# PAGE HAS NO LINKS: /wiki/Geodesic
# PAGE HAS NO LINKS: /wiki/Geographic_coordinate_system
# PAGE HAS NO LINKS: /wiki/Horizontal_position_representation
# PAGE HAS NO LINKS: /wiki/Latitude
# PAGE HAS NO LINKS: /wiki/Longitude
# PAGE HAS NO LINKS: /wiki/Map_projection
# PAGE HAS NO LINKS: /wiki/Reference_ellipsoid
# PAGE HAS NO LINKS: /wiki/Satellite_geodesy
# PAGE HAS NO LINKS: /wiki/Spatial_reference_system
# PAGE HAS NO LINKS: /wiki/Spatial_relation
# PAGE HAS NO LINKS: /wiki/Satellite_navigation
# PAGE HAS NO LINKS: /wiki/Global_Positioning_System
# PAGE HAS NO LINKS: /wiki/GLONASS
# PAGE HAS NO LINKS: /wiki/BeiDou
# PAGE HAS NO LINKS: /wiki/Galileo_(satellite_navigation)
# PAGE HAS NO LINKS: /wiki/Indian_Regional_Navigation_Satellite_System
# PAGE HAS NO LINKS: /wiki/Quasi-Zenith_Satellite_System
# PAGE HAS NO LINKS: /wiki/Discrete_Global_Grid
# PAGE HAS NO LINKS: /wiki/Sea_Level_Datum_of_1929
# PAGE HAS NO LINKS: /wiki/OSGB36
# PAGE HAS NO LINKS: /wiki/SK-42_reference_system
# PAGE HAS NO LINKS: /wiki/ED50
# PAGE HAS NO LINKS: /wiki/South_American_Datum#SAD69
# PAGE HAS NO LINKS: /wiki/GRS_80
# PAGE HAS NO LINKS: /wiki/ISO_6709
# PAGE HAS NO LINKS: /wiki/North_American_Datum#North_American_Datum_of_1983
# PAGE HAS NO LINKS: /wiki/World_Geodetic_System
# PAGE HAS NO LINKS: /wiki/North_American_Vertical_Datum_of_1988
# PAGE HAS NO LINKS: /wiki/European_Terrestrial_Reference_System_1989
# PAGE HAS NO LINKS: /wiki/Restrictions_on_geographic_data_in_China
# PAGE HAS NO LINKS: /wiki/Geo_URI_scheme
# PAGE HAS NO LINKS: /wiki/International_Terrestrial_Reference_System
# PAGE HAS NO LINKS: /wiki/SRID
# PAGE HAS NO LINKS: /wiki/Universal_Transverse_Mercator_coordinate_system
# PAGE HAS NO LINKS: /wiki/Grid_reference
# PAGE HAS NO LINKS: /wiki/Latitude
# PAGE HAS NO LINKS: /wiki/Longitude
# PAGE HAS NO LINKS: /wiki/Ordnance_Survey
# PAGE HAS NO LINKS: /wiki/British_Isles
# PAGE HAS NO LINKS: /wiki/Isle_of_Man
# PAGE HAS NO LINKS: /wiki/Irish_grid_reference_system
# PAGE HAS NO LINKS: /wiki/Ordnance_Survey_of_Ireland
# PAGE HAS NO LINKS: /wiki/Ordnance_Survey_of_Northern_Ireland
# PAGE HAS NO LINKS: /wiki/Universal_Transverse_Mercator_coordinate_system
# PAGE HAS NO LINKS: /wiki/Channel_Islands
# PAGE HAS NO LINKS: /wiki/Irish_Transverse_Mercator
# PAGE HAS NO LINKS: /wiki/Military_Grid_Reference_System
# PAGE HAS NO LINKS: /wiki/The_Wash
# PAGE HAS NO LINKS: /wiki/North_Sea
# PAGE HAS NO LINKS: /wiki/Lincolnshire
# PAGE HAS NO LINKS: /wiki/Norfolk
# PAGE HAS NO LINKS: /wiki/North_Yorkshire
# PAGE HAS NO LINKS: /wiki/Beast_Cliff
# PAGE HAS NO LINKS: /wiki/Ben_Nevis
# PAGE HAS NO LINKS: /wiki/Royal_Observatory_Greenwich
# PAGE HAS NO LINKS: /wiki/Orkney
# PAGE HAS NO LINKS: /wiki/Sullom_Voe
# PAGE HAS NO LINKS: /wiki/Ordnance_Survey#GB_map_range
# PAGE HAS NO LINKS: /wiki/Map_datum
# PAGE HAS NO LINKS: /wiki/George_Biddell_Airy
# PAGE HAS NO LINKS: /wiki/Reference_ellipsoid
# PAGE HAS NO LINKS: /wiki/Retriangulation_of_Great_Britain
# PAGE HAS NO LINKS: /wiki/Cassini_Grid
# PAGE HAS NO LINKS: /wiki/World_War_II
# PAGE HAS NO LINKS: /wiki/Global_Positioning_System
# PAGE HAS NO LINKS: /wiki/Geodetic_Reference_System_1980
# PAGE HAS NO LINKS: /wiki/Transverse_Mercator_projection
# PAGE HAS NO LINKS: /wiki/49th_parallel_north
# PAGE HAS NO LINKS: /wiki/2nd_meridian_west
# PAGE HAS NO LINKS: /wiki/English_Channel
# PAGE HAS NO LINKS: /wiki/Jersey
# PAGE HAS NO LINKS: /wiki/Saint-Malo
# PAGE HAS NO LINKS: /wiki/World_Geodetic_System
# PAGE HAS NO LINKS: /wiki/British_Admiralty
# PAGE HAS NO LINKS: /wiki/Nautical_chart
# PAGE HAS NO LINKS: /wiki/World_Geodetic_System
# PAGE HAS NO LINKS: /wiki/Geodesy
# PAGE HAS NO LINKS: /wiki/International_Terrestrial_Reference_System
# PAGE HAS NO LINKS: /wiki/ETRS89
# PAGE HAS NO LINKS: /wiki/World_Geodetic_System
# PAGE HAS NO LINKS: /wiki/Helmert_transformation
# PAGE HAS NO LINKS: /wiki/Longitude
# PAGE HAS NO LINKS: /wiki/Latitude
# PAGE HAS NO LINKS: /wiki/World_Geodetic_System
# PAGE HAS NO LINKS: /wiki/Cornwall
# PAGE HAS NO LINKS: /wiki/East_Anglia
# PAGE HAS NO LINKS: /wiki/Cornwall
# PAGE HAS NO LINKS: /wiki/Scottish_Borders
# PAGE HAS NO LINKS: /wiki/Scotland
# PAGE HAS NO LINKS: /wiki/Kent
# PAGE HAS NO LINKS: /wiki/English_Channel
# PAGE HAS NO LINKS: /wiki/Dover
# PAGE HAS NO LINKS: /wiki/Calais
# PAGE HAS NO LINKS: /wiki/ED50
# PAGE HAS NO LINKS: /wiki/Datum_(geodesy)
# PAGE HAS NO LINKS: /wiki/Map_projection
# PAGE HAS NO LINKS: /wiki/Transverse_Mercator_projection
# PAGE HAS NO LINKS: /wiki/49th_parallel_north
# PAGE HAS NO LINKS: /wiki/2nd_meridian_west
# PAGE HAS NO LINKS: /wiki/EPSG
# PAGE HAS NO LINKS: /wiki/Reference_ellipsoid
# PAGE HAS NO LINKS: /wiki/Semi-major_axis
# PAGE HAS NO LINKS: /wiki/Semi-minor_axis
# PAGE HAS NO LINKS: /wiki/Flattening
# PAGE HAS NO LINKS: /wiki/World_Geodetic_System
# PAGE HAS NO LINKS: /wiki/Irish_grid_reference_system
# PAGE HAS NO LINKS: /wiki/United_States_National_Grid
# PAGE HAS NO LINKS: /wiki/Tetrad_(unit_of_area)
# PAGE HAS NO LINKS: /wiki/Hectad_(unit_of_area)
# PAGE HAS NO LINKS: /wiki/Myriad_(unit_of_area)
# PAGE HAS NO LINKS: /wiki/International_Map_of_the_World#Map_Indexing_System
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Districts_of_England
# PAGE HAS NO LINKS: /wiki/England
# PAGE HAS NO LINKS: /wiki/Metropolitan_and_non-metropolitan_counties_of_England
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1972
# PAGE HAS NO LINKS: /wiki/London_Government_Act_1963
# PAGE HAS NO LINKS: /wiki/List_of_English_districts
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/Non-metropolitan_district
# PAGE HAS NO LINKS: /wiki/Unitary_authorities_of_England
# PAGE HAS NO LINKS: /wiki/London_boroughs
# PAGE HAS NO LINKS: /wiki/City_status_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Royal_borough
# PAGE HAS NO LINKS: /wiki/Borough_status_in_England_and_Wales
# PAGE HAS NO LINKS: /wiki/Subdivisions_of_England
# PAGE HAS NO LINKS: /wiki/Local_government_in_England
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/London_boroughs
# PAGE HAS NO LINKS: /wiki/Non-metropolitan_district
# PAGE HAS NO LINKS: /wiki/Unitary_authorities_of_England
# PAGE HAS NO LINKS: /wiki/City_of_London
# PAGE HAS NO LINKS: /wiki/Isles_of_Scilly
# PAGE HAS NO LINKS: /wiki/City_status_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Borough
# PAGE HAS NO LINKS: /wiki/Royal_borough
# PAGE HAS NO LINKS: /wiki/Mayors_in_England
# PAGE HAS NO LINKS: /wiki/Directly_elected_mayors_in_England_and_Wales
# PAGE HAS NO LINKS: /wiki/Subdivisions_of_England
# PAGE HAS NO LINKS: /wiki/Church_of_England
# PAGE HAS NO LINKS: /wiki/Vestry#Vestry_committees_in_England_and_Wales
# PAGE HAS NO LINKS: /wiki/Secular
# PAGE HAS NO LINKS: /wiki/Hundred_(county_subdivision)
# PAGE HAS NO LINKS: /wiki/Judicial
# PAGE HAS NO LINKS: /wiki/County_towns
# PAGE HAS NO LINKS: /wiki/Poor_Law_Union
# PAGE HAS NO LINKS: /wiki/English_Poor_Laws
# PAGE HAS NO LINKS: /wiki/Registration_district
# PAGE HAS NO LINKS: /wiki/Sanitary_district
# PAGE HAS NO LINKS: /wiki/Local_Government_Act_1894
# PAGE HAS NO LINKS: /wiki/Urban_district_(Great_Britain_and_Ireland)
# PAGE HAS NO LINKS: /wiki/Rural_district
# PAGE HAS NO LINKS: /wiki/Administrative_county
# PAGE HAS NO LINKS: /wiki/Civil_parish
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/County_of_London
# PAGE HAS NO LINKS: /wiki/London_boroughs
# PAGE HAS NO LINKS: /wiki/Shire_counties
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/Non-metropolitan_district
# PAGE HAS NO LINKS: /wiki/Greater_London_Council
# PAGE HAS NO LINKS: /wiki/Greater_London_Authority
# PAGE HAS NO LINKS: /wiki/Unitary_authorities_of_England
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/Metropolitan_county
# PAGE HAS NO LINKS: /wiki/Non-metropolitan_district
# PAGE HAS NO LINKS: /wiki/County_council
# PAGE HAS NO LINKS: /wiki/Shire_county
# PAGE HAS NO LINKS: /wiki/Council_house
# PAGE HAS NO LINKS: /wiki/Unitary_authorities_of_England
# PAGE HAS NO LINKS: /wiki/Rutland
# PAGE HAS NO LINKS: /wiki/Herefordshire
# PAGE HAS NO LINKS: /wiki/Isle_of_Wight
# PAGE HAS NO LINKS: /wiki/Berkshire
# PAGE HAS NO LINKS: /wiki/Cornwall
# PAGE HAS NO LINKS: /wiki/County_Durham
# PAGE HAS NO LINKS: /wiki/Isle_of_Wight
# PAGE HAS NO LINKS: /wiki/Northumberland
# PAGE HAS NO LINKS: /wiki/Shropshire
# PAGE HAS NO LINKS: /wiki/Wiltshire
# PAGE HAS NO LINKS: /wiki/London_boroughs
# PAGE HAS NO LINKS: /wiki/Greater_London
# PAGE HAS NO LINKS: /wiki/Greater_London_Council
# PAGE HAS NO LINKS: /wiki/Greater_London_Authority
# PAGE HAS NO LINKS: /wiki/London_boroughs#London_borough_councils
# PAGE HAS NO LINKS: /wiki/List_of_English_districts_by_population
# PAGE HAS NO LINKS: /wiki/List_of_English_districts_by_area
# PAGE HAS NO LINKS: /wiki/List_of_local_governments_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Wayback_Machine
# PAGE HAS NO LINKS: /wiki/England
# PAGE HAS NO LINKS: /wiki/Subdivisions_of_England
# PAGE HAS NO LINKS: /wiki/Regions_of_England
# PAGE HAS NO LINKS: /wiki/NUTS_1_statistical_regions_of_England
# PAGE HAS NO LINKS: /wiki/Counties_of_England
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Metropolitan_county
# PAGE HAS NO LINKS: /wiki/Non-metropolitan_county
# PAGE HAS NO LINKS: /wiki/Greater_London
# PAGE HAS NO LINKS: /wiki/Civil_parish
# PAGE HAS NO LINKS: /wiki/Civil_parish
# PAGE HAS NO LINKS: /wiki/Metropolitan_borough
# PAGE HAS NO LINKS: /wiki/Non-metropolitan_district
# PAGE HAS NO LINKS: /wiki/London_boroughs
# PAGE HAS NO LINKS: /wiki/Unitary_authorities_of_England
# PAGE HAS NO LINKS: /wiki/City_of_London
# PAGE HAS NO LINKS: /wiki/Isles_of_Scilly
# PAGE HAS NO LINKS: /wiki/Administrative_geography_of_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Local_government_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/History_of_local_government_in_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/List_of_shrievalties
# PAGE HAS NO LINKS: /wiki/Lieutenancy_area
# PAGE HAS NO LINKS: /wiki/Counties_of_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/List_of_counties_of_the_United_Kingdom
# PAGE HAS NO LINKS: /wiki/Local_government_in_England
# PAGE HAS NO LINKS: /wiki/History_of_local_government_in_England
# PAGE HAS NO LINKS: /wiki/Subdivisions_of_England
# PAGE HAS NO LINKS: /wiki/Regions_of_England
# PAGE HAS NO LINKS: /wiki/Ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/List_of_ceremonial_counties_of_England
# PAGE HAS NO LINKS: /wiki/Metropolitan_and_non-metropolitan_counties_of_England
# PAGE HAS NO LINKS: /wiki/Unitary_authorities_of_England
# PAGE HAS NO LINKS: /wiki/List_of_English_districts
# PAGE HAS NO LINKS: /wiki/Civil_parishes_in_England
# PAGE HAS NO LINKS: /wiki/List_of_civil_parishes_in_England
# PAGE HAS NO LINKS: /wiki/Historic_counties_of_England
# PAGE HAS NO LINKS: /wiki/Local_government_in_Northern_Ireland
# PAGE HAS NO LINKS: /wiki/Local_government_in_Northern_Ireland#History
# PAGE HAS NO LINKS: /wiki/Counties_of_Northern_Ireland
# PAGE HAS NO LINKS: /wiki/Districts_of_Northern_Ireland
# PAGE HAS NO LINKS: /wiki/Local_government_in_Scotland
# PAGE HAS NO LINKS: /wiki/History_of_local_government_in_Scotland
# PAGE HAS NO LINKS: /wiki/Subdivisions_of_Scotland
# PAGE HAS NO LINKS: /wiki/Sheriffdom
# PAGE HAS NO LINKS: /wiki/Lieutenancy_areas_of_Scotland
# PAGE HAS NO LINKS: /wiki/Council_areas_of_Scotland
# PAGE HAS NO LINKS: /wiki/List_of_community_council_areas_in_Scotland
# PAGE HAS NO LINKS: /wiki/List_of_civil_parishes_in_Scotland
# PAGE HAS NO LINKS: /wiki/Shires_of_Scotland
# PAGE HAS NO LINKS: /wiki/Local_government_in_Wales
# PAGE HAS NO LINKS: /wiki/History_of_local_government_in_Wales
# PAGE HAS NO LINKS: /wiki/Preserved_counties_of_Wales
# PAGE HAS NO LINKS: /wiki/Local_government_in_Wales
# PAGE HAS NO LINKS: /wiki/Community_(Wales)
# PAGE HAS NO LINKS: /wiki/List_of_communities_in_Wales
# PAGE HAS NO LINKS: /wiki/Historic_counties_of_Wales
# PAGE HAS NO LINKS: /wiki/England
# PAGE HAS NO LINKS: /wiki/History_of_England
# PAGE HAS NO LINKS: /wiki/Timeline_of_English_history
# PAGE HAS NO LINKS: /wiki/History_of_education_in_England
# PAGE HAS NO LINKS: /wiki/History_of_local_government_in_England
# PAGE HAS NO LINKS: /wiki/Maritime_history_of_England
# PAGE HAS NO LINKS: /wiki/Military_history_of_England
# PAGE HAS NO LINKS: /wiki/English_society
# PAGE HAS NO LINKS: /wiki/Prehistoric_Britain
# PAGE HAS NO LINKS: /wiki/Roman_Britain
# PAGE HAS NO LINKS: /wiki/Lloegyr
# PAGE HAS NO LINKS: /wiki/History_of_Anglo-Saxon_England
# PAGE HAS NO LINKS: /wiki/Heptarchy
# PAGE HAS NO LINKS: /wiki/Kingdom_of_England
# PAGE HAS NO LINKS: /wiki/Norman_Conquest
# PAGE HAS NO LINKS: /wiki/Angevin_Empire
# PAGE HAS NO LINKS: /wiki/Wars_of_the_Roses
# PAGE HAS NO LINKS: /wiki/Tudor_period
# PAGE HAS NO LINKS: /wiki/Stuart_period
# PAGE HAS NO LINKS: /wiki/English_Renaissance
# PAGE HAS NO LINKS: /wiki/English_Reformation
# PAGE HAS NO LINKS: /wiki/Elizabethan_era
# PAGE HAS NO LINKS: /wiki/Jacobean_era
# PAGE HAS NO LINKS: /wiki/English_Civil_War
# PAGE HAS NO LINKS: /wiki/Acts_of_Union_1707
# PAGE HAS NO LINKS: /wiki/Georgian_era
# PAGE HAS NO LINKS: /wiki/Regency_era
# PAGE HAS NO LINKS: /wiki/Victorian_era
# PAGE HAS NO LINKS: /wiki/Edwardian_era
# PAGE HAS NO LINKS: /wiki/The_Blitz
# PAGE HAS NO LINKS: /wiki/England
# PAGE HAS NO LINKS: /wiki/Geography_of_England
# PAGE HAS NO LINKS: /wiki/Counties_of_England
# PAGE HAS NO LINKS: /wiki/List_of_gardens_in_England
# PAGE HAS NO LINKS: /wiki/List_of_islands_of_England
# PAGE HAS NO LINKS: /wiki/List_of_civil_parishes_in_England
# PAGE HAS NO LINKS: /wiki/List_of_places_in_England
# PAGE HAS NO LINKS: /wiki/Regions_of_England
# PAGE HAS NO LINKS: /wiki/List_of_towns_in_England
# PAGE HAS NO LINKS: /wiki/Politics_of_England
# PAGE HAS NO LINKS: /wiki/Economy_of_England
# PAGE HAS NO LINKS: /wiki/Economy_of_England_in_the_Middle_Ages
# PAGE HAS NO LINKS: /wiki/Elizabethan_government
# PAGE HAS NO LINKS: /wiki/English_independence
# PAGE HAS NO LINKS: /wiki/List_of_English_monarchs
# PAGE HAS NO LINKS: /wiki/Parliament_of_England
# PAGE HAS NO LINKS: /wiki/Culture_of_England
# PAGE HAS NO LINKS: /wiki/Afternoon_tea
# PAGE HAS NO LINKS: /wiki/Anglophile
# PAGE HAS NO LINKS: /wiki/English_art
# PAGE HAS NO LINKS: /wiki/List_of_castles_in_England
# PAGE HAS NO LINKS: /wiki/British_country_clothing
# PAGE HAS NO LINKS: /wiki/English_cuisine
# PAGE HAS NO LINKS: /wiki/List_of_cultural_icons_of_England
# PAGE HAS NO LINKS: /wiki/Demography_of_England
# PAGE HAS NO LINKS: /wiki/Education_in_England
# PAGE HAS NO LINKS: /wiki/English_folklore
# PAGE HAS NO LINKS: /wiki/F%C3%AAte
# PAGE HAS NO LINKS: /wiki/English_landscape_garden
# PAGE HAS NO LINKS: /wiki/English_national_identity
# PAGE HAS NO LINKS: /wiki/List_of_English_inventions_and_discoveries
# PAGE HAS NO LINKS: /wiki/English_language_in_England
# PAGE HAS NO LINKS: /wiki/Middle_England
# PAGE HAS NO LINKS: /wiki/List_of_museums_in_England
# PAGE HAS NO LINKS: /wiki/English_people
# PAGE HAS NO LINKS: /wiki/List_of_English_people
# PAGE HAS NO LINKS: /wiki/Religion_in_England
# PAGE HAS NO LINKS: /wiki/Church_of_England
# PAGE HAS NO LINKS: /wiki/Science_education_in_England
# PAGE HAS NO LINKS: /wiki/Sunday_roast
# PAGE HAS NO LINKS: /wiki/Sport_in_England
# PAGE HAS NO LINKS: /wiki/Cricket_in_England
# PAGE HAS NO LINKS: /wiki/England_cricket_team
# PAGE HAS NO LINKS: /wiki/Football_in_England
# PAGE HAS NO LINKS: /wiki/The_Football_Association
# PAGE HAS NO LINKS: /wiki/England_national_football_team
# PAGE HAS NO LINKS: /wiki/Rugby_league_in_England
# PAGE HAS NO LINKS: /wiki/Rugby_Football_League
# PAGE HAS NO LINKS: /wiki/England_national_rugby_league_team
# PAGE HAS NO LINKS: /wiki/Rugby_union_in_England
# PAGE HAS NO LINKS: /wiki/Rugby_Football_Union
# PAGE HAS NO LINKS: /wiki/England_national_rugby_union_team
# PAGE HAS NO LINKS: /wiki/The_Championships,_Wimbledon
# PAGE HAS NO LINKS: /wiki/National_symbols_of_England
# PAGE HAS NO LINKS: /wiki/National_anthem_of_England
# PAGE HAS NO LINKS: /wiki/Royal_arms_of_England
# PAGE HAS NO LINKS: /wiki/List_of_English_flags
# PAGE HAS NO LINKS: /wiki/Flag_of_England
# PAGE HAS NO LINKS: /wiki/English_heraldry
# PAGE HAS NO LINKS: /wiki/Oak
# PAGE HAS NO LINKS: /wiki/Royal_standards_of_England
# PAGE HAS NO LINKS: /wiki/Royal_supporters_of_England
# PAGE HAS NO LINKS: /wiki/Saint_George
# PAGE HAS NO LINKS: /wiki/Saint_George%27s_Day_in_England
# PAGE HAS NO LINKS: /wiki/Tudor_rose
# PAGE HAS NO LINKS: /wiki/Outline_of_England
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Main_Page
# PAGE HAS NO LINKS: /wiki/Metropolitan_Borough_of_Rotherham
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-523ecbfe5ed9> in <module>
# ----> 1 getLinks('/wiki/Kevin_Bacon', 0, loadPages())
#       2 cur.close()
#       3 conn.close()
#
# <ipython-input-25-5387edb26193> in getLinks(pageUrl, recursionLevel, pages)
#      19             print("PAGE HAS NO LINKS: {}".format(link))
#      20             pages.append(link) # 페이지 리스트에 추가
# ---> 21             getLinks(link, recursionLevel+1, pages)
#
# <ipython-input-25-5387edb26193> in getLinks(pageUrl, recursionLevel, pages)
#      19             print("PAGE HAS NO LINKS: {}".format(link))
#      20             pages.append(link) # 페이지 리스트에 추가
# ---> 21             getLinks(link, recursionLevel+1, pages)
#
# <ipython-input-25-5387edb26193> in getLinks(pageUrl, recursionLevel, pages)
#      19             print("PAGE HAS NO LINKS: {}".format(link))
#      20             pages.append(link) # 페이지 리스트에 추가
# ---> 21             getLinks(link, recursionLevel+1, pages)
#
# <ipython-input-25-5387edb26193> in getLinks(pageUrl, recursionLevel, pages)
#      19             print("PAGE HAS NO LINKS: {}".format(link))
#      20             pages.append(link) # 페이지 리스트에 추가
# ---> 21             getLinks(link, recursionLevel+1, pages)
#
# <ipython-input-25-5387edb26193> in getLinks(pageUrl, recursionLevel, pages)
#       6
#       7     pageId = insertPageIfNotExists(pageUrl) # fromPageId
# ----> 8     html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
#       9     bs = BeautifulSoup(html, 'html.parser')
#      10
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1395
#    1396         def https_open(self, req):
# -> 1397             return self.do_open(http.client.HTTPSConnection, req,
#    1398                 context=self._context, check_hostname=self._check_hostname)
#    1399
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1356             except OSError as err: # timeout error
#    1357                 raise URLError(err)
# -> 1358             r = h.getresponse()
#    1359         except:
#    1360             h.close()
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 이메일 활용하기

# %%
# SMTP 서버를 로컬에서 실행하기
import smtplib
from email.mime.text import MIMEText

msg = MIMEText('The body of the email is here')

msg['Subject'] = 'An Email Alert'
msg['From'] = 'ryan@pythonscraping.com'
msg['To'] = 'webmaster@pythonscraping.com'

s = smtplib.SMTP('localhost')
s.send_message(msg)
s.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-27-7ee0b4781fb2> in <module>
#       8 msg['To'] = 'webmaster@pythonscraping.com'
#       9
# ---> 10 s = smtplib.SMTP('localhost')
#      11 s.send_message(msg)
#      12 s.quit()
#
# ~\anaconda3\lib\smtplib.py in __init__(self, host, port, local_hostname, timeout, source_address)
#     251
#     252         if host:
# --> 253             (code, msg) = self.connect(host, port)
#     254             if code != 220:
#     255                 self.close()
#
# ~\anaconda3\lib\smtplib.py in connect(self, host, port, source_address)
#     335             port = self.default_port
#     336         sys.audit("smtplib.connect", self, host, port)
# --> 337         self.sock = self._get_socket(host, port, self.timeout)
#     338         self.file = None
#     339         (code, msg) = self.getreply()
#
# ~\anaconda3\lib\smtplib.py in _get_socket(self, host, port, timeout)
#     306         if self.debuglevel > 0:
#     307             self._print_debug('connect: to', (host, port), self.source_address)
# --> 308         return socket.create_connection((host, port), timeout,
#     309                                         self.source_address)
#     310
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
#     807         try:
# --> 808             raise err
#     809         finally:
#     810             # Break explicitly a reference cycle
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     794             if source_address:
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#     798             err = None
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다

# %%
# 크리스마스일 때 메일 보내기
import smtplib
from email.mime.text import MIMEText
from bs4 import BeautifulSoup
from urllib.request import urlopen
import time

def sendMail(subject, body):
    msg = MIMEText(body)
    msg['Subject'] = subject
    msg['From'] ='christmas_alerts@pythonscraping.com'
    msg['To'] = 'ryan@pythonscraping.com'

    s = smtplib.SMTP('localhost')
    s.send_message(msg)
    s.quit()

bs = BeautifulSoup(urlopen('https://isitchristmas.com/'), 'html.parser')
while(bs.find('a', {'id':'answer'}).attrs['title'] == 'NO'):
    print('It is not Christmas yet.')
    time.sleep(3600) # 한 시간마다 웹사이트 체크
    bs = BeautifulSoup(urlopen('https://isitchristmas.com/'), 'html.parser')
    
sendMail('It\'s Christmas!', 
         'According to http://itischristmas.com, it is Christmas!')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-28-f3c272fe7e55> in <module>
#      22     bs = BeautifulSoup(urlopen('https://isitchristmas.com/'), 'html.parser')
#      23
# ---> 24 sendMail('It\'s Christmas!',
#      25          'According to http://itischristmas.com, it is Christmas!')
#
# <ipython-input-28-f3c272fe7e55> in sendMail(subject, body)
#      12     msg['To'] = 'ryan@pythonscraping.com'
#      13
# ---> 14     s = smtplib.SMTP('localhost')
#      15     s.send_message(msg)
#      16     s.quit()
#
# ~\anaconda3\lib\smtplib.py in __init__(self, host, port, local_hostname, timeout, source_address)
#     251
#     252         if host:
# --> 253             (code, msg) = self.connect(host, port)
#     254             if code != 220:
#     255                 self.close()
#
# ~\anaconda3\lib\smtplib.py in connect(self, host, port, source_address)
#     335             port = self.default_port
#     336         sys.audit("smtplib.connect", self, host, port)
# --> 337         self.sock = self._get_socket(host, port, self.timeout)
#     338         self.file = None
#     339         (code, msg) = self.getreply()
#
# ~\anaconda3\lib\smtplib.py in _get_socket(self, host, port, timeout)
#     306         if self.debuglevel > 0:
#     307             self._print_debug('connect: to', (host, port), self.source_address)
# --> 308         return socket.create_connection((host, port), timeout,
#     309                                         self.source_address)
#     310
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
#     807         try:
# --> 808             raise err
#     809         finally:
#     810             # Break explicitly a reference cycle
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     794             if source_address:
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#     798             err = None
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
